# %%
import fitz

pdf = fitz.open("../Stock Trader's Almanac 2026_L.pdf")

print("Pages:", len(pdf))
# Out:
# Pages: 273

# %%
for page_num in range(len(pdf)):

    text = pdf[page_num].get_text()

    if "MAY ALMANAC" in text:
        print("Found on page:", page_num + 1)
# Out:
# Found on page: 2
# Found on page: 65

# %%
for page_num in range(64, 70):

    print("\n")
    print("=" * 80)
    print("PAGE", page_num + 1)
    print("=" * 80)

    text = pdf[page_num].get_text()

    print(text[:5000])
# Out:
# ...
# PAGE 65
# ...
# MAY ALMANAC
# Market Probability Chart above is a graphic representation of the S&P 500 Recent
# Market Probability Calendar on page 126.
# ◆ “May/June disaster area” between 1965 and 1984 with S&P down 15 out of 20
# Mays ◆ Between 1985 and 1997 May was the best month with 13 straight gains,
# gaining 3.3% per year on average, up 19, down 9 since ◆ Worst six months of the year
# begin with May (page 54) ◆ A $10,000 investment compounded to $1,316,635 gain
# for November-April in 75 years compared to a $4,253 gain for May-October ◆ Dow
# Memorial Day week record: up 12 years in a row (1984-1995), down 17 of the last 30
# years ◆ Since 1950 midterm election year Mays rank, #8 Dow, #9 S&P and #6
# NASDAQ
# May Vital Statistics
# DJIA
# S&P 500
# NASDAQ
# Russell 1K Russell 2K
# Rank
# 9
# 8
# 5
# 6
# 4
# Up
# 41
# 46
# 33
# 32
# 29
# Down
# 34
# 29
# 21
# 14
# 17
# Average % Change
# –0.02
# 0.3
# 1.1
# 0.9
# 1.3
# Midterm Yr Avg %
# Chg
# –0.6
# –0.7
# –0.8
# 0.1
# –1.0
# ...

# %%
page = pdf[64]

pix = page.get_pixmap(
    matrix=fitz.Matrix(3,3)
)

pix.save("may_almanac_page.png")

print("saved")
# Out:
# saved

# %%
may_stats = {
    "Month": "May",

    "SP500 Rank": 8,

    "SP500 Up Years": 46,

    "SP500 Down Years": 29,

    "SP500 Average Return": 0.3,

    "SP500 Midterm Year Return": -0.7,

    "Seasonal Bias": "Slightly Bearish"
}

may_stats
# Out:
# {'Month': 'May',
#  'SP500 Rank': 8,
#  'SP500 Up Years': 46,
#  'SP500 Down Years': 29,
#  'SP500 Average Return': 0.3,
#  'SP500 Midterm Year Return': -0.7,
#  'Seasonal Bias': 'Slightly Bearish'}

# %%
import pandas as pd

evidence = {
    "Evidence": [
        "May ranks #8 for S&P 500",
        "Average May return is +0.3%",
        "Midterm Year average return is -0.7%",
        "May starts the Worst Six Months"
    ],

    "Impact": [
        "Neutral",
        "Bullish",
        "Bearish",
        "Bearish"
    ]
}

evidence_df = pd.DataFrame(evidence)

evidence_df
# Out:
#                                Evidence   Impact
# 0              May ranks #8 for S&P 500  Neutral
# 1           Average May return is +0.3%  Bullish
# 2  Midterm Year average return is -0.7%  Bearish
# 3       May starts the Worst Six Months  Bearish

# %%
almanac_agent = {
    "Month": "May",

    "Bias": "Slightly Bearish",

    "Confidence": "Medium",

    "Bullish Factors": [
        "Average May return is +0.3%",
        "46 up years vs 29 down years"
    ],

    "Bearish Factors": [
        "Midterm Year average return is -0.7%",
        "May begins the Worst Six Months"
    ]
}

almanac_agent
# Out:
# {'Month': 'May',
#  'Bias': 'Slightly Bearish',
#  'Confidence': 'Medium',
#  'Bullish Factors': ['Average May return is +0.3%',
#   '46 up years vs 29 down years'],
#  'Bearish Factors': ['Midterm Year average return is -0.7%',
#   'May begins the Worst Six Months']}

# %%
for page_num in range(len(pdf)):

    text = pdf[page_num].get_text()

    if "Memorial Day" in text:
        print("Found on page:", page_num + 1)
        print("-" * 50)
        print(text[:2000])
        print("\n")
# Out:
# Found on page: 65
# --------------------------------------------------
# MAY ALMANAC
# Market Probability Chart above is a graphic representation of the S&P 500 Recent
# Market Probability Calendar on page 126.
# ◆ “May/June disaster area” between 1965 and 1984 with S&P down 15 out of 20
# Mays ◆ Between 1985 and 1997 May was the best month with 13 straight gains,
# gaining 3.3% per year on average, up 19, down 9 since ◆ Worst six months of the year
# begin with May (page 54) ◆ A $10,000 investment compounded to $1,316,635 gain
# for November-April in 75 years compared to a $4,253 gain for May-October ◆ Dow
# Memorial Day week record: up 12 years in a row (1984-1995), down 17 of the last 30
# years ◆ Since 1950 midterm election year Mays rank, #8 Dow, #9 S&P and #6
# NASDAQ
# May Vital Statistics
# DJIA
# S&P 500
# NASDAQ
# Russell 1K Russell 2K
# Rank
# 9
# 8
# 5
# 6
# 4
# Up
# 41
# 46
# 33
# 32
# 29
# Down
# 34
# 29
# 21
# 14
# 17
# Average % Change
# –0.02
# 0.3
# 1.1
# 0.9
# 1.3
# ...

# %%
memorial_pages = []

for page_num in range(len(pdf)):

    text = pdf[page_num].get_text()

    if "Memorial Day" in text:
        memorial_pages.append(page_num + 1)

print(memorial_pages)
# Out:
# [65, 67, 75, 78, 111, 112]

# %%
keywords = [
    "Memorial Day",
    "Midterm",
    "Worst Six Months",
    "Best Six Months"
]

for keyword in keywords:

    print("\nSearching:", keyword)

    for page_num in range(len(pdf)):

        text = pdf[page_num].get_text()

        if keyword in text:

            print(
                f"Found on page {page_num+1}"
            )
# Out:
# Searching: Memorial Day
# Found on page 65
# Found on page 67
# Found on page 75
# Found on page 78
# Found on page 111
# Found on page 112
#
# Searching: Midterm
# Found on page 12
# Found on page 13
# Found on page 14
# Found on page 18
# Found on page 30
# Found on page 38
# Found on page 40
# Found on page 45
# Found on page 56
# Found on page 65
# Found on page 80
# Found on page 88
# Found on page 92
# Found on page 103
# Found on page 114
# Found on page 116
# Found on page 127
# Found on page 135
# Found on page 137
# Found on page 138
# Found on page 149
# Found on page 175
#
# Searching: Worst Six Months
# Found on page 12
# Found on page 129
# Found on page 130
# Found on page 146
#
# Searching: Best Six Months
# Found on page 30
# Found on page 56
# Found on page 64
# Found on page 69
# Found on page 72
# Found on page 75
# Found on page 88
# Found on page 127
# Found on page 130
# Found on page 135
# Found on page 139
# Found on page 146

# %%
page = pdf[127]

pix = page.get_pixmap(
    matrix=fitz.Matrix(3,3)
)

pix.save(
    "memorial_day_evidence.png"
)

print("saved")
# Out:
# saved

# %%
for page_num in range(len(pdf)):
    text = pdf[page_num].get_text()
    if "Memorial Day" in text:
        print("Found on page:", page_num + 1)
# Out:
# Found on page: 65
# Found on page: 67
# Found on page: 75
# Found on page: 78
# Found on page: 111
# Found on page: 112

# %%
for page_num in [66, 74, 77]:

    page = pdf[page_num]

    pix = page.get_pixmap(
        matrix=fitz.Matrix(3,3)
    )

    pix.save(
        f"page_{page_num+1}.png"
    )

print("Done")
# Out:
# Done

# %%
Worst six months of the year begin with May

This is evidence of bearish sentiment.

    
Memorial Day Week
Dow Down 17 of Last 29
Up 12 Straight 1984-1995

Historical Bias = Bearish


Day After Memorial Day

Dow Up 23 of Last 39
But Down 8 of Last 10

Mixed Signal

# %%
week2_evidence = {
    "Evidence": [
        "May begins the Worst Six Months",
        "Midterm Year May return is -0.7%",
        "Memorial Day Week down 17 of last 29 years",
        "Day After Memorial Day down 8 of last 10 years"
    ],

    "Impact": [
        "Bearish",
        "Bearish",
        "Bearish",
        "Slightly Bearish"
    ]
}

week2_evidence
# Out:
# {'Evidence': ['May begins the Worst Six Months',
#   'Midterm Year May return is -0.7%',
#   'Memorial Day Week down 17 of last 29 years',
#   'Day After Memorial Day down 8 of last 10 years'],
#  'Impact': ['Bearish', 'Bearish', 'Bearish', 'Slightly Bearish']}

# %%
import pandas as pd

evidence_df = pd.DataFrame(week2_evidence)

evidence_df
# Out:
#                                          Evidence            Impact
# 0                 May begins the Worst Six Months           Bearish
# 1                Midterm Year May return is -0.7%           Bearish
# 2      Memorial Day Week down 17 of last 29 years           Bearish
# 3  Day After Memorial Day down 8 of last 10 years  Slightly Bearish

# %%
almanac_agent = {
    "Month": "May",

    "Bias": "Bearish",

    "Confidence": "Medium",

    "Bullish Factors": [
        "Average May return +0.3%",
        "46 up years versus 29 down years"
    ],

    "Bearish Factors": [
        "Midterm Year average return -0.7%",
        "May begins Worst Six Months",
        "Memorial Day Week down 17 of last 29 years",
        "Day After Memorial Day down 8 of last 10 years"
    ],

    "Final Verdict":
        "Bearish"
}

almanac_agent
# Out:
# {'Month': 'May',
#  'Bias': 'Bearish',
#  'Confidence': 'Medium',
#  'Bullish Factors': ['Average May return +0.3%',
#   '46 up years versus 29 down years'],
#  'Bearish Factors': ['Midterm Year average return -0.7%',
#   'May begins Worst Six Months',
#   'Memorial Day Week down 17 of last 29 years',
#   'Day After Memorial Day down 8 of last 10 years'],
#  'Final Verdict': 'Bearish'}

# %%
evidence_df.to_csv(
    "week2_almanac_evidence.csv",
    index=False
)

print("Week2 Evidence Saved")
# Out:
# Week2 Evidence Saved

# %%
week2_md = """# Week 2 Almanac Agent Output

## Role

R3 – Almanac Lead

---

## Month

May 2026

---

## Almanac Research Summary

According to the Stock Trader's Almanac, May marks the beginning of the Worst Six Months of the year (May–October).

Although May has historically produced a positive average return for the S&P 500, Midterm Election Years have shown weaker performance.

As 2026 is a Midterm Election Year, historical seasonality suggests a cautious outlook.

---

## Bullish Factors

1. S&P 500 average May return: +0.3%

2. S&P 500 recorded 46 up years versus 29 down years

3. NASDAQ average May return: +1.1%

4. Russell 2000 average May return: +1.3%

---

## Bearish Factors

1. Midterm Election Year S&P 500 average May return: -0.7%

2. May begins the Worst Six Months period

3. Memorial Day Week:
   - Dow down 17 of the last 29 years

4. Day After Memorial Day:
   - Dow down 8 of the last 10 years

5. Midterm Election Years historically experience weakness during Q2 and Q3

---

## Key Evidence

| Evidence | Impact |
|-----------|-----------|
| May begins Worst Six Months | Bearish |
| Midterm Year May return -0.7% | Bearish |
| Memorial Day Week down 17 of last 29 years | Bearish |
| Day After Memorial Day down 8 of last 10 years | Slightly Bearish |
| Average May return +0.3% | Bullish |

---

## Confidence

Medium

---

## Final Verdict

Bearish

---

## Recommendation to AI Synthesis Team

Historical seasonality suggests that May 2026 carries elevated downside risk due to:

- Midterm Election Year weakness
- Start of the Worst Six Months period
- Weak Memorial Day Week statistics

The Almanac Agent therefore assigns a Bearish outlook with Medium confidence.
"""

with open(
    "week2_almanac.md",
    "w",
    encoding="utf-8"
) as f:
    f.write(week2_md)

print("week2_almanac.md created successfully")
# Out:
# week2_almanac.md created successfully
